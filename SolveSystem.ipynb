# %% [markdown]
# <a href="https://colab.research.google.com/github/rifaldibpn2/Computing/blob/main/SolveSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = [[8,3,-3],[-2,-8,5],[3,5,10]]

# %%
diag = np.diag(np.abs(a))

# %%
off_diag = np.sum(np.abs(a), axis=1) -diag

# %%
if np.all(diag > off_diag):
  print('matrix is diagonally dominant')
else:
  print('NOT diagonally dominant')
# Out:
# matrix is diagonally dominant

# %% [markdown]
# Since it is guaranteed to converge, we can use Gauss-Seidel Method to solve it

# %%
x1=0
x2=0
x3=0
epsilon=0.01
converged=False

# %%
x_old=np.array([x1,x2,x3])

print("Iteration result")
print("k,   x1  ,   x2   ,   x3   ")
for k in range(1,50):
  x1=(14-3*x2+3*x3)/8
  x2=(5+2*x1-5*x3)/(-8)
  x3=(-8-3*x1-5*x2)/(10)
  x=np.array([x1,x2,x3])
  #chech if it is smaller than threshold
  dx=np.sqrt(np.dot(x-x_old,x-x_old))

  print("%d, %.4f, %.4f, %.4f"%(k,x1,x2,x3))
  if dx<epsilon:
    converged=True
    print("Converged!")
    break

  #assing the latest x value to the old value
  x_old=x

if not converged:
  print("Not converge, increase the # of iterations")
# Out:
# Iteration result
# k,   x1  ,   x2   ,   x3
# 1, 1.7500, -1.0625, -0.7937
# 2, 1.8508, -1.5838, -0.5633
# 3, 2.1327, -1.5103, -0.6847
# 4, 2.0596, -1.5678, -0.6340
# 5, 2.1002, -1.5463, -0.6569
# 6, 2.0835, -1.5565, -0.6468
# 7, 2.0911, -1.5520, -0.6513
# Converged!

# %% [markdown]
# Use numpy.linalg.solve

# %%
import numpy as np

A = np.array([[4, 3, -5],
             [-2, -4, 5],
             [8, 8, 0]])
y = np.array([2, 5, -3])

x = np.linalg.solve(A, y)
print(x)
# Out:
# [ 2.20833333 -2.58333333 -0.18333333]

# %% [markdown]
# Using the matrix inversion approach

# %%
A_inv = np.linalg.inv(A)

x = np.dot(A_inv, y)
print(x)
# Out:
# [ 2.20833333 -2.58333333 -0.18333333]
